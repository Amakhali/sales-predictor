# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# plt.style.use('seaborn')

# %%
df = pd.read_csv('../data/sample_data/Sales_Product_Details.csv')

# %%
print("Dataset Shape:", df.shape)
print("nColumns:", df.columns.tolist())
print("nData Types:", df.dtypes)
print("nMissing Values:", df.isnull().sum())
# Out:
# Dataset Shape: (30, 13)
# nColumns: ['Date', 'Customer_ID', 'Product_ID', 'Quantity', 'Unit_Price', 'Sales_Revenue', 'Product_Description', 'Product_Category', 'Product_Line', 'Raw_Material', 'Region', 'Latitude', 'Longitude']
# nData Types: Date                     int64
# Customer_ID              int64
# Product_ID               int64
# Quantity                 int64
# Unit_Price             float64
# Sales_Revenue          float64
# Product_Description     object
# Product_Category        object
# Product_Line            object
# Raw_Material            object
# Region                  object
# Latitude               float64
# Longitude              float64
# dtype: object
# nMissing Values: Date                   0
# Customer_ID            0
# Product_ID             0
# Quantity               0
# Unit_Price             0
# Sales_Revenue          0
# Product_Description    0
# Product_Category       0
# Product_Line           0
# Raw_Material           0
# ...

# %%
# Convert Date to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Daily sales trend
daily_sales = df.groupby('Date')['Sales_Revenue'].sum().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(daily_sales['Date'], daily_sales['Sales_Revenue'])
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales Revenue')
plt.xticks(rotation=45)
plt.show()
